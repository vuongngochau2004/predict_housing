# %%
import pandas as pd

data = pd.read_csv('nhatot_real_estate.csv')
print(data)
# Out:
#       Giá bán       Thành phố                           Phường/Xã  \
# 0     15,5 tỷ  Tp Hồ Chí Minh         Phường An Khánh (Quận 2 cũ)
# 1      1,7 tỷ      Bình Dương                     Phường Bình Hòa
# 2   11,868 tỷ  Tp Hồ Chí Minh                   Phường Hiệp Thành
# 3      4,9 tỷ  Tp Hồ Chí Minh                           Phường 16
# 4       19 tỷ      Bình Dương                    Phường Phú Cường
# 5     7,15 tỷ  Tp Hồ Chí Minh  Phường Linh Đông (Quận Thủ Đức cũ)
# 6   980 triệu  Tp Hồ Chí Minh                Phường Tân Thới Nhất
# 7      4,1 tỷ  Tp Hồ Chí Minh                           Phường 16
# 8     7,49 tỷ  Tp Hồ Chí Minh                            Phường 9
# 9      7,5 tỷ  Tp Hồ Chí Minh                           Phường 25
# 10    1,58 tỷ         Long An                      Xã Mỹ Hạnh Bắc
# 11     4,5 tỷ  Tp Hồ Chí Minh                   Phường Thạnh Xuân
# 12    26,8 tỷ  Tp Hồ Chí Minh                           Phường 19
# ...
